# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('historical_emissions.csv')

# %%
df.Country.nunique()
# Out:
# 193

# %%
allghg = df[df.Gas == 'All GHG'][df.Sector == 'Total excluding LUCF']
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
allghg[allghg.columns.tolist()[5:]]
# Out:
#           2014      2013      2012      2011      2010      2009      2008  \
# 0        33.37     33.17     34.50     34.71     30.63     26.94     23.63
# 29        9.04      8.56      8.37      8.79      8.31      8.03      7.96
# 40      202.09    187.52    182.33    171.75    165.59     24.32      6.84
# 77        0.52      0.53      0.54      0.54      0.57      0.00      0.00
# 80      157.82    155.87    150.53    151.12    147.69    137.17    127.00
# 100       1.13      1.10      1.07      1.03      1.02      0.99      0.93
# 133     348.65    334.24    333.96    328.20    320.16    319.77    335.52
# 140       8.63      8.59      8.60      7.71      7.07      7.25      8.38
# 160     589.73    580.10    648.61    646.98    561.62    587.80    573.52
# 180      75.15     78.47     78.16     81.11     82.82     77.91     84.33
# 200      72.60     69.72     67.45     63.56     57.40     55.79     57.58
# ...

# %%
def row_total(x):
    return  np.sum(x.tolist()[5:])

# %%
allghg['total'] = allghg.apply(lambda x: row_total(x), axis = 1)

# %%
allghg
# Out:
#                      Country Data source                Sector      Gas  \
# 0                Afghanistan        CAIT  Total excluding LUCF  All GHG
# 29                   Albania        CAIT  Total excluding LUCF  All GHG
# 40                   Algeria        CAIT  Total excluding LUCF  All GHG
# 77                   Andorra        CAIT  Total excluding LUCF  All GHG
# 80                    Angola        CAIT  Total excluding LUCF  All GHG
# 100      Antigua and Barbuda        CAIT  Total excluding LUCF  All GHG
# 133                Argentina        CAIT  Total excluding LUCF  All GHG
# 140                  Armenia        CAIT  Total excluding LUCF  All GHG
# 160                Australia        CAIT  Total excluding LUCF  All GHG
# 180                  Austria        CAIT  Total excluding LUCF  All GHG
# 200               Azerbaijan        CAIT  Total excluding LUCF  All GHG
# 220                  Bahamas        CAIT  Total excluding LUCF  All GHG
# ...

# %%
top6 = allghg.sort_values(by = 'total', ascending = False).iloc[:6]

# %%
top6[['Country'] + allghg.columns.tolist()[5:-1][::-1]].set_index('Country').transpose()
# Out:
# Country     World     China  United States  European Union (28)   Russia  \
# 1990     29964.04   3154.46        5866.64              5244.24  2982.76
# 1991     30149.06   3301.90        5831.48              5188.32  2922.70
# 1992     30068.55   3438.39        5914.71              5017.73  2707.85
# 1993     30191.77   3665.44        6041.83              4922.75  2486.62
# 1994     30372.09   3819.92        6122.58              4893.56  2233.04
# 1995     31062.62   4205.00        6179.62              4919.87  2142.95
# 1996     31630.42   4221.13        6339.44              5028.99  2104.78
# 1997     31953.86   4252.72        6502.05              4923.17  1986.00
# 1998     32176.62   4359.20        6511.31              4899.92  1970.55
# 1999     32446.04   4293.66        6533.04              4825.67  2001.35
# 2000     33261.16   4480.39        6728.36              4815.09  2037.38
# 2001     33751.10   4721.70        6684.73              4867.33  2048.05
# ...

# %%
top6[['Country'] + allghg.columns.tolist()[5:-1][::-1]].set_index('Country').transpose().to_csv('top6.csv')

# %%
pop = pd.read_csv('pop.csv')

# %%
rest = pop.sort_values('Population', ascending = False)[['Country','Population']][5:].Population.sum()

# %%
top5 = pop.sort_values('Population', ascending = False)[['Country','Population']][:5].reset_index(drop = True)

# %%
top5 = top5.append({'Country':'Rest', 'Population': rest}, ignore_index= True)

# %%
top5.to_csv('popu.csv', index=False)

# %%
df['total'] = df.apply(lambda x: row_total(x), axis = 1)

# %%
df.groupby('Sector').total.sum().sort_values(ascending = False)[2:8]
# Out:
# Sector
# Energy                        1481506.43
# Electricity/Heat               615118.58
# Transportation                 298507.63
# Agriculture                    250959.72
# Manufacturing/Construction     242624.07
# Other Fuel Combustion          215126.16
# Name: total, dtype: float64

# %%
df[df['Country'] == 'China'][['Sector', 'total']]
# Out:
#                            Sector      total
# 700          Total excluding LUCF  163062.58
# 701          Total including LUCF  154621.79
# 702          Total excluding LUCF  131829.06
# 703          Total excluding LUCF   19625.14
# 704          Total excluding LUCF    9380.86
# 705          Total excluding LUCF    2227.52
# 706          Total including LUCF  123361.27
# 707          Total including LUCF   19641.04
# 708          Total including LUCF    9391.96
# 709                        Energy  127474.16
# 710          Industrial Processes   15188.68
# 711                   Agriculture   15747.33
# 712                         Waste    4652.37
# 713  Land-Use Change and Forestry   -8440.77
# 714                  Bunker Fuels     573.53
# 715              Electricity/Heat   59169.68
# 716    Manufacturing/Construction   38633.11
# 717                Transportation    8841.17
# 718         Other Fuel Combustion   15477.29
# 719            Fugitive Emissions    5352.89

# %%
df[df['Country'] == 'United States'][['Sector', 'total']]
# Out:
#                             Sector      total
# 3660                Transportation   41183.07
# 3661    Manufacturing/Construction   12442.52
# 3662              Electricity/Heat   63500.52
# 3663          Industrial Processes    5389.83
# 3664            Fugitive Emissions    7786.99
# 3665                        Energy  141969.69
# 3666         Other Fuel Combustion   17056.63
# 3667          Total excluding LUCF   15846.60
# 3668                         Waste    3960.62
# 3669          Total including LUCF    7026.80
# 3670  Land-Use Change and Forestry   -7175.00
# 3671          Total excluding LUCF    6943.50
# 3672                   Agriculture    8725.07
# 3673          Total including LUCF  152870.20
# 3674          Total excluding LUCF  133776.52
# 3675                  Bunker Fuels    3416.72
# 3676          Total excluding LUCF  160045.22
# 3677          Total excluding LUCF    3478.56
# 3678          Total including LUCF  126131.55
# ...

# %%
np.arange(0,150001,10000).tolist()
# Out:
# [0,
#  10000,
#  20000,
#  30000,
#  40000,
#  50000,
#  60000,
#  70000,
#  80000,
#  90000,
#  100000,
#  110000,
#  120000,
#  130000,
#  140000,
#  150000]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
from pylab import rcParams
rcParams['figure.figsize'] = 15,15
 
# Set data
df = pd.DataFrame({
'group': ['A','B'],
#'Energy': [141969,127474],
'Electricity/Heat': [63500, 59169],
'Transportation': [41183.07, 8841],
'Agriculture': [8725, 15747],
'Manufacturing/Construction': [12442, 38633],
    'Other Fuel Combustion ': [17056, 15477]
})
 
 
 
# ------- PART 1: Create background
 
# number of variable
categories=list(df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks(np.arange(10000,70001,10000).tolist(), ["10000","20000","30000","40000","50000","60000","70000 MtCO₂e"], color="grey", size=7)
plt.ylim(0,70000)
 
 #,"80000","90000","100000","110000","120000","130000","140000","150000"
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="United States")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="China")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.title('United States vs. China in Main Sectors of Emissions')
# Out:
# Text(0.5, 1.05, 'United States vs. China in Main Sectors of Emissions')

# %% [markdown]
# Hi everybody, most of us should believe the existence of global warming and gas emissions are the main cause of it. So today our topic is about every country's contribution to global warming through out the year, and spoiler alert, how urgen† it is for Uni†ed States to take the most serious actions to reduce its gas emissions.
#
# We collect our data from World Bank Open Data. It has 3861 rows of data about 191 countries' all types of green house gases emission from 1990 to 2014.
#
# Graph
#
# Here is our first graph, a line chart. We display the World total, and China, United States, European Union, India and Russia who are top five highest GHG emissions from 1990 to 2014 in total.
#
# The United States and China's total greenhouse gas emission from 1990 to 2014 are about the same and China surpassed USA in 2005 as the highest GHG emission country. However we need to keep in mind that China has four times more population than America.
#
# Graph
#
# Let's look at this pie chart that shows ratios of countries with the most populations.
# China actually has been executing the one-child policy for decades as an effort. We should not blame a country for having too many people. So by average per person, we would say that United States are the number one contributor of greenhouse gas emssion to global warming.
#
# Graph
#
# Now Let's look at a timeline graph mainly focused on Unite States'role in the world during the past three decades.
#
# Graph
#
# To understand which sectors of greenhouse gas emission United States and China are producing compared to each other, we will look at this radar chart that compares five major sectors of emissions.
# We can see United States create far more emission in transportation sector. That's expected since America has the most automobiles in the world. China is a developing country that do not have that a lot of private cars. So we think United States really should consider taking actions to encourage people to commute in a more green way, like riding a bike or taking buses or electricy car.
